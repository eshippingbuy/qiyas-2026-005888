# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://edition.cnn.com/2026/06/08/politics/iran-talks-deadlocked-hostage-negotiation'
pages = requests.get(url)

# %%
pages.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(pages.text,'html.parser')
# print(soup.prettify())

# %%
table_content= soup.find(class_ = "paragraph-elevate inline-placeholder vossi-paragraph_elevate")
print(table_content.text)
# Out:
#             As President Donald Trump searches for a way to reopen the Strait of Hormuz and curtail Iran’s nuclear ambitions, Washington and Tehran appear to be engaged in a standard negotiation.
